# %%
import pandas as pd
import matplotlib.pyplot as plt
 
# Get totals for each category
grocery_total = get_totals(grocery_dict, 'grocery', 0)
home_total = get_totals(home_dict, 'home', 0)
food_total = get_totals(food_dict, 'food', 0)
retail_total = get_totals(retail_dict, 'retail', 0)
gas_total = get_totals(gas_dict, 'gas', 0)
 
# Create a pandas DataFrame
spending_data = {
    "Category": ["Grocery", "Home", "Food", "Retail", "Gas"],
    "Amount Spent": [grocery_total, home_total, food_total, retail_total, gas_total]
}
 
df = pd.DataFrame(spending_data)
 
# Print the table so user can see exact totals
print(df)
 
# Create pie chart
df.plot(
    kind="pie",
    y="Amount Spent",
    labels=df["Category"],
    autopct="%1.1f%%",
    legend=False,
    title="Spending by Category"
)
 
plt.ylabel("")  # removes y-axis label
plt.show()
